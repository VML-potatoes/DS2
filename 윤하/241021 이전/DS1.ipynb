# %% [markdown]
# ### 데이터사이언스

# %%
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train_data = pd.read_csv('datas/train.csv')
test_data = pd.read_csv('datas/test.csv')

# %%
# 데이터프레임 기본 정보 확인
train_data.info()

# 데이터프레임의 첫 5행 출력
train_data.head()

# 열별 분석
for i in range(28):  # 열의 개수가 28개인 경우
    column_name = train_data.columns[i]
    print(f"\n--- 열: {column_name} ---")
    
    # 열의 값 분포 확인
    print("항목별 개수:")
    print(train_data.iloc[:, i].value_counts())
    
    # 열의 기본 통계량 출력 (숫자형인 경우)
    if train_data.iloc[:, i].dtype in ['int64', 'float64']:
        print("\n기본 통계분석:")
        print(train_data.iloc[:, i].describe())
    
    # 결측치 여부 확인
    missing_values = train_data.iloc[:, i].isnull().sum()
    print(f"\n결측치 개수: {missing_values}")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1644768 entries, 0 to 1644767
# Data columns (total 28 columns):
#  #   Column                         Non-Null Count    Dtype
# ---  ------                         --------------    -----
#  0   User                           1644768 non-null  int64
#  1   Gender                         1644768 non-null  int64
#  2   Current Age                    1644768 non-null  int64
#  3   Retirement Age                 1644768 non-null  int64
#  4   Birth Year                     1644768 non-null  int64
#  5   Birth Month                    1644768 non-null  int64
#  6   Zipcode                        1644768 non-null  float64
#  7   Per Capita Income - Zipcode    1644768 non-null  int64
#  8   Yearly Income                  1644768 non-null  float64
#  9   Total Debt                     1644768 non-null  float64
#  10  Credit Score                   1644768 non-null  int64
#  11  Year                           1644768 non-null  int64
#  12  Month                          1644768 non-null  int64
#  13  Day                            1644768 non-null  int64
#  14  Merchandise Code               1644768 non-null  int64
#  15  Card                           1644768 non-null  int64
#  16  Card Brand                     1644768 non-null  object
#  17  Card Type                      1644768 non-null  object
#  18  Card Number                    1644768 non-null  float64
#  19  Expires                        1644768 non-null  object
#  20  Has Chip                       1644768 non-null  bool
#  21  Credit Limit                   1644768 non-null  int64
#  22  Acct Open Date                 1644768 non-null  object
#  23  Year PIN last Changed          1644768 non-null  int64
#  24  Amount                         1644768 non-null  float64
#  25  Whether Security Chip is Used  1644768 non-null  int64
#  26  Error Message                  25766 non-null    object
#  27  Is Fraud?                      1644768 non-null  object
# dtypes: bool(1), float64(5), int64(16), object(6)
# memory usage: 340.4+ MB
#
# --- 열: User ---
# 항목별 개수:
# User
# 1249    4928
# 1101    4326
# 396     4317
# 262     4313
# 808     4093
#         ...
# 1319     143
# 1631     129
# 208      119
# 871       53
# 529        2
# Name: count, Length: 1509, dtype: int64
#
# 기본 통계분석:
# count    1.644768e+06
# mean     1.004376e+03
# std      5.695082e+02
# min      0.000000e+00
# 25%      5.170000e+02
# 50%      1.010000e+03
# 75%      1.479000e+03
# max      1.999000e+03
# Name: User, dtype: float64
#
# 결측치 개수: 0
#
# --- 열: Gender ---
# 항목별 개수:
# Gender
# 0    849376
# 1    795392
# Name: count, dtype: int64
#
# 기본 통계분석:
# count    1.644768e+06
# mean     4.835892e-01
# std      4.997308e-01
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      1.000000e+00
# max      1.000000e+00
# Name: Gender, dtype: float64
#
# 결측치 개수: 0
#
# --- 열: Current Age ---
# 항목별 개수:
# Current Age
# 47     57527
# 51     48447
# 49     43905
# 48     42820
# 50     41993
#        ...
# 20      2227
# 101     1527
# 99      1406
# 93       846
# 22       753
# Name: count, Length: 78, dtype: int64
#
# 기본 통계분석:
# count    1.644768e+06
# mean     5.229045e+01
# std      1.622627e+01
# min      2.000000e+01
# 25%      4.000000e+01
# 50%      5.000000e+01
# 75%      6.200000e+01
# max      1.010000e+02
# Name: Current Age, dtype: float64
#
# 결측치 개수: 0
#
# --- 열: Retirement Age ---
# 항목별 개수:
# Retirement Age
# 65    266419
# 66    262593
# 67    230055
# 68    163110
# 69    126988
# 64     89669
# 70     76979
# 71     67935
# 72     50361
# 62     49540
# 63     46541
# 61     41903
# 73     35213
# 60     31289
# 59     24299
# 57     16556
# 58     15537
# 74     13980
# 75     13347
# 54      6378
# 55      4448
# 56      2732
# 78      2567
# 53      1913
# 79      1342
# 50      1329
# 76       885
# 77       860
# Name: count, dtype: int64
#
# 기본 통계분석:
# count    1.644768e+06
# mean     6.637021e+01
# std      3.570074e+00
# min      5.000000e+01
# 25%      6.500000e+01
# 50%      6.600000e+01
# 75%      6.800000e+01
# max      7.900000e+01
# Name: Retirement Age, dtype: float64
#
# 결측치 개수: 0
#
# --- 열: Birth Year ---
# 항목별 개수:
# Birth Year
# 1972    52827
# 1970    51120
# 1968    50917
# 1961    44738
# 1967    43154
#         ...
# 1928     2394
# 1999     2227
# 1918     1527
# 1920     1406
# 1997      753
# Name: count, Length: 77, dtype: int64
#
# 기본 통계분석:
# count    1.644768e+06
# mean     1.966894e+03
# std      1.621924e+01
# min      1.918000e+03
# 25%      1.957000e+03
# 50%      1.969000e+03
# 75%      1.979000e+03
# max      1.999000e+03
# Name: Birth Year, dtype: float64
#
# 결측치 개수: 0
#
# --- 열: Birth Month ---
# 항목별 개수:
# Birth Month
# 11    174406
# 2     151861
# 1     151186
# 3     144283
# 10    143900
# 5     138357
# 12    135720
# 8     133714
# 7     126386
# 9     125410
# 4     121265
# 6      98280
# Name: count, dtype: int64
#
# 기본 통계분석:
# count    1.644768e+06
# mean     6.519760e+00
# std      3.575366e+00
# min      1.000000e+00
# 25%      3.000000e+00
# 50%      7.000000e+00
# 75%      1.000000e+01
# max      1.200000e+01
# Name: Birth Month, dtype: float64
#
# 결측치 개수: 0
#
# --- 열: Zipcode ---
# 항목별 개수:
# Zipcode
# 1484.0     5046
# 48998.0    4928
# 89537.0    4688
# 12879.0    4474
# 59701.0    4454
#            ...
# 7870.0      152
# 51788.0     143
# 55517.0     119
# 9956.0       53
# 39479.0       2
# Name: count, Length: 1404, dtype: int64
#
# 기본 통계분석:
# count    1.644768e+06
# mean     4.988484e+04
# std      2.965987e+04
# min      4.920000e+02
# 25%      2.265400e+04
# 50%      5.387600e+04
# 75%      7.229600e+04
# max      9.889300e+04
# Name: Zipcode, dtype: float64
#
# 결측치 개수: 0
#
# --- 열: Per Capita Income - Zipcode ---
# 항목별 개수:
# Per Capita Income - Zipcode
# 0           7971
# 10056095    6099
# 15551515    5907
# 14306180    5046
# 15194515    4688
#             ...
# 9818095      154
# 5151510      143
# 9139795      119
# 7355390       53
# 55298110       2
# Name: count, Length: 1366, dtype: int64
#
# 기본 통계분석:
# count    1.644768e+06
# mean     1.425004e+07
# std      6.912591e+06
# min      0.000000e+00
# 25%      1.017688e+07
# 50%      1.262530e+07
# 75%      1.641546e+07
# max      9.707128e+07
# Name: Per Capita Income - Zipcode, dtype: float64
#
# 결측치 개수: 0
#
# --- 열: Yearly Income ---
# 항목별 개수:
# Yearly Income
# 24354600.0     4928
# 13498600.0     4326
# 26970800.0     4317
# 31937900.0     4313
# 46432800.0     4093
#                ...
# 8888900.0       143
# 21646000.0      129
# 18121700.0      119
# 12089800.0       53
# 121560100.0       2
# Name: count, Length: 1506, dtype: int64
#
# 기본 통계분석:
# count    1.644768e+06
# mean     2.792330e+07
# std      1.552382e+07
# min      5.000000e+02
# 25%      1.834940e+07
# 50%      2.457150e+07
# 75%      3.386700e+07
# max      1.578132e+08
# Name: Yearly Income, dtype: float64
#
# 결측치 개수: 0
#
# --- 열: Total Debt ---
# 항목별 개수:
# Total Debt
# 0.000000e+00    85204
# 3.800387e+07     4928
# 2.731999e+05     4326
# 2.053036e+07     4317
# 4.307058e+07     4313
#                 ...
# 1.190961e+07      143
# 5.110325e+07      129
# 2.349009e+07      119
# 2.516030e+07       53
# 2.236589e+08        2
# Name: count, Length: 1432, dtype: int64
#
# 기본 통계분석:
# count    1.644768e+06
# mean     3.623609e+07
# std      3.406705e+07
# min      0.000000e+00
# 25%      1.014754e+07
# 50%      3.117703e+07
# 75%      5.165649e+07
# max      3.171627e+08
# Name: Total Debt, dtype: float64
#
# 결측치 개수: 0
#
# --- 열: Credit Score ---
# 항목별 개수:
# Credit Score
# 693    14203
# 780    12553
# 687    12424
# 697    12226
# 803    11903
#        ...
# 506      471
# 567      450
# 882      419
# 560      405
# 613      350
# Name: count, Length: 420, dtype: int64
#
# 기본 통계분석:
# count    1.644768e+06
# mean     7.111466e+02
# std      9.857789e+01
# min      4.030000e+02
# 25%      6.450000e+02
# 50%      7.130000e+02
# 75%      7.770000e+02
# max      1.057000e+03
# Name: Credit Score, dtype: float64
#
# 결측치 개수: 0
#
# --- 열: Year ---
# 항목별 개수:
# Year
# 2018    1644768
# Name: count, dtype: int64
#
# 기본 통계분석:
# count    1644768.0
# mean        2018.0
# std            0.0
# min         2018.0
# 25%         2018.0
# 50%         2018.0
# 75%         2018.0
# max         2018.0
# Name: Year, dtype: float64
#
# 결측치 개수: 0
#
# --- 열: Month ---
# 항목별 개수:
# Month
# 12    141625
# 8     140976
# 7     140264
# 10    140131
# 5     138428
# 3     138298
# 1     137977
# 11    137163
# 9     136166
# 6     135479
# 4     134341
# 2     123920
# Name: count, dtype: int64
#
# 기본 통계분석:
# count    1.644768e+06
# mean     6.558884e+00
# std      3.446594e+00
# min      1.000000e+00
# 25%      4.000000e+00
# 50%      7.000000e+00
# 75%      1.000000e+01
# max      1.200000e+01
# Name: Month, dtype: float64
#
# 결측치 개수: 0
#
# --- 열: Day ---
# 항목별 개수:
# Day
# 25    55093
# 21    54746
# 7     54632
# 1     54591
# 15    54492
# 18    54468
# 14    54436
# 28    54409
# 8     54136
# 23    54124
# 22    54081
# 27    54076
# 6     54067
# 24    54041
# 11    53985
# 20    53945
# 3     53940
# 9     53926
# 5     53882
# 4     53877
# 26    53828
# 10    53753
# 17    53745
# 16    53725
# 13    53684
# 19    53673
# 2     53637
# 12    53169
# 29    49866
# 30    49372
# 31    31369
# Name: count, dtype: int64
#
# 기본 통계분석:
# count    1.644768e+06
# mean     1.573131e+01
# std      8.798610e+00
# min      1.000000e+00
# 25%      8.000000e+00
# 50%      1.600000e+01
# 75%      2.300000e+01
# max      3.100000e+01
# Name: Day, dtype: float64
#
# 결측치 개수: 0
#
# --- 열: Merchandise Code ---
# 항목별 개수:
# Merchandise Code
# 5411    196371
# 5499    176115
# 5541    170788
# 5812    121372
# 5912     95097
#          ...
# 3007        44
# 3006        44
# 5722        42
# 3075        30
# 4411        27
# Name: count, Length: 109, dtype: int64
#
# 기본 통계분석:
# count    1.644768e+06
# mean     5.554929e+03
# std      8.810854e+02
# min      1.711000e+03
# 25%      5.300000e+03
# 50%      5.499000e+03
# 75%      5.812000e+03
# max      9.402000e+03
# Name: Merchandise Code, dtype: float64
#
# 결측치 개수: 0
#
# --- 열: Card ---
# 항목별 개수:
# Card
# 0    623679
# 1    431166
# 2    291482
# 3    177044
# 4     74895
# 5     31986
# 6     11435
# 7      2906
# 8       175
# Name: count, dtype: int64
#
# 기본 통계분석:
# count    1.644768e+06
# mean     1.273811e+00
# std      1.369525e+00
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      1.000000e+00
# 75%      2.000000e+00
# max      8.000000e+00
# Name: Card, dtype: float64
#
# 결측치 개수: 0
#
# --- 열: Card Brand ---
# 항목별 개수:
# Card Brand
# Mastercard    880944
# Visa          616574
# Others        147250
# Name: count, dtype: int64
#
# 결측치 개수: 0
#
# --- 열: Card Type ---
# 항목별 개수:
# Card Type
# Debit              1024236
# Credit              509970
# Debit (Prepaid)     110562
# Name: count, dtype: int64
#
# 결측치 개수: 0
#
# --- 열: Card Number ---
# 항목별 개수:
# Card Number
# 4.447648e+15    3986
# 4.190554e+15    3225
# 4.690059e+15    3007
# 4.404438e+15    2805
# 9.647603e+15    2798
#                 ...
# 5.387992e+15       1
# 4.886367e+15       1
# 5.379092e+15       1
# 5.270047e+15       1
# 4.227126e+15       1
# Name: count, Length: 3777, dtype: int64
#
# 기본 통계분석:
# count    1.644768e+06
# mean     5.163251e+15
# std      1.289868e+15
# min      3.005502e+15
# 25%      4.420395e+15
# 50%      4.894334e+15
# 75%      5.504827e+15
# max      9.699390e+15
# Name: Card Number, dtype: float64
#
# 결측치 개수: 0
#
# --- 열: Expires ---
# 항목별 개수:
# Expires
# 02/2020    68581
# 08/2023    34189
# 10/2024    34110
# 07/2024    34030
# 03/2020    33374
# 09/2023    33276
# 03/2024    33123
# 10/2021    32351
# 07/2023    31436
# 05/2022    31325
# 12/2023    31255
# 01/2021    30605
# 12/2022    30396
# 06/2022    29742
# 02/2021    29699
# 10/2020    29552
# 09/2020    29499
# 05/2021    29343
# 06/2020    28928
# 02/2024    28641
# 11/2020    28549
# 04/2020    28369
# 12/2020    28325
# 05/2023    28271
# 09/2021    27996
# 10/2023    27961
# 01/2023    27731
# 03/2022    27415
# 04/2021    27272
# 11/2022    27050
# 05/2020    26831
# 08/2022    26408
# 06/2021    26354
# 12/2024    26298
# 11/2024    26271
# 09/2022    26159
# 07/2022    26102
# 06/2024    25510
# 04/2023    25451
# 07/2020    24971
# 10/2022    24891
# 01/2024    24260
# 07/2021    24222
# 01/2020    24129
# 04/2022    24044
# 04/2024    23918
# 06/2023    23855
# 03/2023    23745
# 01/2022    23494
# 09/2024    23347
# 08/2020    22832
# 02/2022    21838
# 08/2021    21425
# 03/2021    20929
# 11/2023    20835
# 08/2024    20154
# 11/2021    19618
# 02/2023    19376
# 05/2024    18555
# 12/2021    16552
# Name: count, dtype: int64
#
# 결측치 개수: 0
#
# --- 열: Has Chip ---
# 항목별 개수:
# Has Chip
# True     1482797
# False     161971
# Name: count, dtype: int64
#
# 결측치 개수: 0
#
# --- 열: Credit Limit ---
# 항목별 개수:
# Credit Limit
# 6307000     7179
# 0           7105
# 5236000     6513
# 7556500     6261
# 5771500     5938
#             ...
# 7500570       34
# 2534700       10
# 38444735       2
# 13286350       1
# 20758360       1
# Name: count, Length: 2456, dtype: int64
#
# 기본 통계분석:
# count    1.644768e+06
# mean     9.160743e+06
# std      7.107103e+06
# min      0.000000e+00
# 25%      4.641000e+06
# 50%      8.032500e+06
# 75%      1.229270e+07
# max      8.412764e+07
# Name: Credit Limit, dtype: float64
#
# 결측치 개수: 0
#
# --- 열: Acct Open Date ---
# 항목별 개수:
# Acct Open Date
# 02/2010    27750
# 10/2009    19475
# 12/2007    17517
# 08/2008    17363
# 04/2010    17064
#            ...
# 04/1997      125
# 03/1998       76
# 01/2019        4
# 06/2019        2
# 04/2019        1
# Name: count, Length: 288, dtype: int64
#
# 결측치 개수: 0
#
# --- 열: Year PIN last Changed ---
# 항목별 개수:
# Year PIN last Changed
# 2011    267877
# 2010    236744
# 2012    163246
# 2013    148767
# 2009    147872
# 2014    137799
# 2015    127373
# 2016     91729
# 2008     90600
# 2007     58858
# 2017     53357
# 2018     48392
# 2006     30620
# 2019     11617
# 2005     11239
# 2020      9682
# 2003      5588
# 2004      3155
# 2002       253
# Name: count, dtype: int64
#
# 기본 통계분석:
# count    1.644768e+06
# mean     2.011822e+03
# std      3.052586e+00
# min      2.002000e+03
# 25%      2.010000e+03
# 50%      2.011000e+03
# 75%      2.014000e+03
# max      2.020000e+03
# Name: Year PIN last Changed, dtype: float64
#
# 결측치 개수: 0
#
# --- 열: Amount ---
# 항목별 개수:
# Amount
#  700.0        11859
#  800.0        11812
#  600.0        11725
#  900.0        11432
#  500.0        11338
#               ...
#  1466500.0        1
# -193900.0         1
# -145200.0         1
#  471600.0         1
#  770800.0         1
# Name: count, Length: 10475, dtype: int64
#
# 기본 통계분석:
# count    1.644768e+06
# mean     2.534947e+04
# std      5.458708e+04
# min     -7.408000e+05
# 25%      3.500000e+03
# 50%      1.400000e+04
# 75%      3.590000e+04
# max      2.936700e+06
# Name: Amount, dtype: float64
#
# 결측치 개수: 0
#
# --- 열: Whether Security Chip is Used ---
# 항목별 개수:
# Whether Security Chip is Used
# 0    1160282
# 2     279102
# 1     205384
# Name: count, dtype: int64
#
# 기본 통계분석:
# count    1.644768e+06
# mean     4.642527e-01
# std      7.668795e-01
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      1.000000e+00
# max      2.000000e+00
# Name: Whether Security Chip is Used, dtype: float64
#
# 결측치 개수: 0
#
# --- 열: Error Message ---
# 항목별 개수:
# Error Message
# Insufficient Balance                     15658
# Bad PIN                                   3924
# Technical Glitch                          3284
# Bad Card Number                           1017
# Bad Expiration                             821
# Bad CVV                                    800
# Bad Zipcode                                150
# Bad PIN,Insufficient Balance                33
# Insufficient Balance,Technical Glitch       32
# Bad CVV,Insufficient Balance                11
# Bad PIN,Technical Glitch                    10
# Bad Card Number,Insufficient Balance         9
# Bad Expiration,Bad CVV                       5
# Bad Card Number,Bad CVV                      3
# Bad Expiration,Technical Glitch              3
# Bad Card Number,Bad Expiration               2
# Bad Expiration,Insufficient Balance          2
# Bad Card Number,Technical Glitch             2
# Name: count, dtype: int64
#
# 결측치 개수: 1619002
#
# --- 열: Is Fraud? ---
# 항목별 개수:
# Is Fraud?
# No     1642447
# Yes       2321
# Name: count, dtype: int64
#
# 결측치 개수: 0

# %%
#라벨링 잔뜩

from sklearn.preprocessing import LabelEncoder

# 1. 라벨 인코딩할 열들 지정
label_cols = ['Card Brand', 'Card Type', 'Error Message', 'Is Fraud?']

# 2. 각 열에 대해 라벨 인코딩 수행
label_encoders = {}
for col in label_cols:
    le = LabelEncoder()
    train_data[col] = le.fit_transform(train_data[col])
    label_encoders[col] = le  # 나중에 필요하면 인코더 저장 (복원할 때 사용 가능)

# 3. 날짜 데이터를 8자리 숫자로 변환
# 'Expires' 변환 (MM/YYYY -> YYYYMMDD)
train_data['Expires'] = train_data['Expires'].apply(lambda x: x.split('/')[1] + x.split('/')[0] + '01')

# 'Acct Open Date' 변환 (MM/YYYY -> YYYYMMDD)
train_data['Acct Open Date'] = train_data['Acct Open Date'].apply(lambda x: x.split('/')[1] + x.split('/')[0] + '01')

# 날짜 형식을 int 타입으로 변환
train_data['Expires'] = train_data['Expires'].astype(int)
train_data['Acct Open Date'] = train_data['Acct Open Date'].astype(int)

# 결과 확인
print(train_data.info())
print(train_data.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1644768 entries, 0 to 1644767
# Data columns (total 28 columns):
#  #   Column                         Non-Null Count    Dtype
# ---  ------                         --------------    -----
#  0   User                           1644768 non-null  int64
#  1   Gender                         1644768 non-null  int64
#  2   Current Age                    1644768 non-null  int64
#  3   Retirement Age                 1644768 non-null  int64
#  4   Birth Year                     1644768 non-null  int64
#  5   Birth Month                    1644768 non-null  int64
#  6   Zipcode                        1644768 non-null  float64
#  7   Per Capita Income - Zipcode    1644768 non-null  int64
#  8   Yearly Income                  1644768 non-null  float64
#  9   Total Debt                     1644768 non-null  float64
#  10  Credit Score                   1644768 non-null  int64
#  11  Year                           1644768 non-null  int64
#  12  Month                          1644768 non-null  int64
#  13  Day                            1644768 non-null  int64
#  14  Merchandise Code               1644768 non-null  int64
#  15  Card                           1644768 non-null  int64
#  16  Card Brand                     1644768 non-null  int32
#  17  Card Type                      1644768 non-null  int32
#  18  Card Number                    1644768 non-null  float64
#  19  Expires                        1644768 non-null  int32
#  20  Has Chip                       1644768 non-null  bool
#  21  Credit Limit                   1644768 non-null  int64
#  22  Acct Open Date                 1644768 non-null  int32
#  23  Year PIN last Changed          1644768 non-null  int64
#  24  Amount                         1644768 non-null  float64
#  25  Whether Security Chip is Used  1644768 non-null  int64
#  26  Error Message                  1644768 non-null  int32
#  27  Is Fraud?                      1644768 non-null  int32
# dtypes: bool(1), float64(5), int32(6), int64(16)
# memory usage: 302.7 MB
# None
#    User  Gender  Current Age  Retirement Age  Birth Year  Birth Month  \
# 0     0       0           53              66        1966           11
# 1     0       0           53              66        1966           11
# 2     0       0           53              66        1966           11
# 3     0       0           53              66        1966           11
# 4     0       0           53              66        1966           11
#
#    Zipcode  Per Capita Income - Zipcode  Yearly Income    Total Debt  ...  \
# 0   8250.0                     17420410     52077100.0  9.088794e+07  ...
# 1   8250.0                     17420410     52077100.0  9.088794e+07  ...
# 2   8250.0                     17420410     52077100.0  9.088794e+07  ...
# 3   8250.0                     17420410     52077100.0  9.088794e+07  ...
# 4   8250.0                     17420410     52077100.0  9.088794e+07  ...
#
#     Card Number   Expires  Has Chip  Credit Limit  Acct Open Date  \
# 0  5.655323e+15  20221201      True      14455525        20020901
# 1  5.655323e+15  20221201      True      14455525        20020901
# 2  5.655323e+15  20221201      True      14455525        20020901
# 3  5.655323e+15  20221201      True      14455525        20020901
# 4  5.655323e+15  20221201      True      14455525        20020901
#
#    Year PIN last Changed    Amount  Whether Security Chip is Used  \
# 0                   2008   84600.0                              0
# 1                   2008   72100.0                              0
# 2                   2008    3300.0                              1
# 3                   2008   56800.0                              0
# 4                   2008  104600.0                              0
#
#    Error Message  Is Fraud?
# 0             18          0
# 1             18          0
# 2             18          0
# 3             18          0
# 4             18          0
#
# [5 rows x 28 columns]

# %%
# 상관관계 계산
correlation_matrix = train_data.corr()

# 상관관계 결과를 CSV로 저장
correlation_csv_path = 'datas/파생/correlation_matrix.csv'
correlation_matrix.to_csv(correlation_csv_path)

# %%
# 히트맵 그리기
plt.figure(figsize=(10, 8))
plt.title("Correlation Heatmap", fontsize=16)
heatmap = plt.imshow(correlation_matrix, cmap='coolwarm', interpolation='none')
plt.colorbar(heatmap)
plt.xticks(np.arange(28), labels=correlation_matrix.columns, rotation=90)
plt.yticks(np.arange(28), labels=correlation_matrix.columns)

plt.tight_layout()
plt.show()

# %%
from autofeat import AutoFeatRegressor

# 모델과 자동 피처 생성기 초기화
afreg = AutoFeatRegressor()
train_data.fillna(0)
# X는 입력 데이터, y는 타겟 값
X_new = afreg.fit_transform(train_data.drop(columns=['Is Fraud?']), train_data['Is Fraud?'])

# 새로 생성된 피처 확인
print(X_new.head())

# %%
import numpy as np
from scipy import stats


#nan, outlier
def analyze_and_handle_missing_data(df):
    # nan확인
    nan_counts = df.isna().sum()
    nan_counts_with_nan = nan_counts[nan_counts > 0]

    # 결측치출력
    for column, count in nan_counts_with_nan.items():
        print(f"{column}: {count}개의 결측치")
        print(f"{column}: {df[column].dtype}")
        print(df[column].value_counts())  # Print non-NaN value counts

    # 결측치 평균으로 대체
    #for column in nan_counts_with_nan.index:
    #    if df[column].dtype in [np.float64, np.int64]:  # Only fill for numeric columns
    #        df[column].fillna(df[column].mean(), inplace=True)

    # outlier
    def detect_outliers_zscore(data):
        z_scores = np.abs(stats.zscore(data))
        return z_scores > 3

    for column in df.select_dtypes(include=[np.number]).columns:
        # Detect outliers using Z-score
        outliers_zscore = detect_outliers_zscore(df[column])
        print(f"Column {column} has {outliers_zscore.sum()} outliers detected by Z-score")
        # Histogram visualization
        plt.figure(figsize=(10, 6))
        
        # Overall data histogram visualization
        sns.histplot(df[column], kde=True, color='lightblue', label='Data', bins=30)
        
        # Outliers data histogram visualization
        sns.histplot(df.loc[outliers_zscore, column], kde=True, color='red', label='Z-score Outliers', bins=30)
        
        plt.title(f'Z-score Outliers Detection in {column}')
        plt.legend()
        plt.show()

    return df

# Example usage:
# cleaned_df = analyze_and_handle_missing_data(your_dataframe)
cleaned_df = analyze_and_handle_missing_data(train_data)
cleaned_df.head(5)
cleaned_df.shape
# Out:
# Column User has 0 outliers detected by Z-score
# Column Gender has 0 outliers detected by Z-score
# Column Current Age has 1527 outliers detected by Z-score
# Column Retirement Age has 17977 outliers detected by Z-score
# Column Birth Year has 1527 outliers detected by Z-score
# Column Birth Month has 0 outliers detected by Z-score
# Column Zipcode has 0 outliers detected by Z-score
# Column Per Capita Income - Zipcode has 19537 outliers detected by Z-score
# Column Yearly Income has 24395 outliers detected by Z-score
# Column Total Debt has 21414 outliers detected by Z-score
# Column Credit Score has 8499 outliers detected by Z-score
# Column Year has 0 outliers detected by Z-score
# Column Month has 0 outliers detected by Z-score
# Column Day has 0 outliers detected by Z-score
# Column Merchandise Code has 12517 outliers detected by Z-score
# Column Card has 14516 outliers detected by Z-score
# Column Card Brand has 0 outliers detected by Z-score
# Column Card Type has 0 outliers detected by Z-score
# Column Card Number has 100262 outliers detected by Z-score
# Column Expires has 0 outliers detected by Z-score
# Column Credit Limit has 22805 outliers detected by Z-score
# Column Acct Open Date has 4755 outliers detected by Z-score
# Column Year PIN last Changed has 253 outliers detected by Z-score
# Column Amount has 24858 outliers detected by Z-score
# Column Whether Security Chip is Used has 0 outliers detected by Z-score
# Column Error Message has 22450 outliers detected by Z-score
# Column Is Fraud? has 2321 outliers detected by Z-score
# (1644768, 28)
