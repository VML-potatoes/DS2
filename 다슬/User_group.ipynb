# %% [markdown]
# ## 1. 유저끼리 묶어서 사기에 존재 여부에 따른 feature 비교
# ## 2. 사기 유저, 사기 아닌 유저 끼리의 공통적인 feature를 가지고 있는지 확인해볼 필요 존재함.
#
# # 여기서 조금 중요한 건 각 유저별로 계속 사기를 당한 게 아니라 어느 시점에서 생긴건데 그게 어떻게 생긴건지 잘 모르곘어.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('Processed_data.csv')
df
# Out:
#          User  Gender  Current Age  Retirement Age  Birth Year  Birth Month  \
# 0           0       0           53              66        1966           11
# 1           0       0           53              66        1966           11
# 2           0       0           53              66        1966           11
# 3           0       0           53              66        1966           11
# 4           0       0           53              66        1966           11
# ...       ...     ...          ...             ...         ...          ...
# 1644763  1999       0           21              60        1998           11
# 1644764  1999       0           21              60        1998           11
# 1644765  1999       0           21              60        1998           11
# 1644766  1999       0           21              60        1998           11
# 1644767  1999       0           21              60        1998           11
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1644768 entries, 0 to 1644767
# Data columns (total 29 columns):
#  #   Column                         Non-Null Count    Dtype
# ---  ------                         --------------    -----
#  0   User                           1644768 non-null  int64
#  1   Gender                         1644768 non-null  int64
#  2   Current Age                    1644768 non-null  int64
#  3   Retirement Age                 1644768 non-null  int64
#  4   Birth Year                     1644768 non-null  int64
#  5   Birth Month                    1644768 non-null  int64
#  6   Zipcode                        1644768 non-null  float64
#  7   Per Capita Income - Zipcode    1644768 non-null  int64
#  8   Yearly Income                  1644768 non-null  float64
#  9   Total Debt                     1644768 non-null  float64
#  10  Credit Score                   1644768 non-null  int64
#  11  Year                           1644768 non-null  int64
# ...

# %%
fraud_count = df['Is Fraud?'].sum()
print('전처리한 데이터의 사기탐지 개수',fraud_count)

data = pd.read_csv('/Users/gidaseul/Documents/GitHub/DS/datas/train.csv')
data['Is Fraud?'] = data['Is Fraud?'].map({'Yes': 1, 'No': 0})
fraud_count_d = data['Is Fraud?'].sum()
print('원본 데이터의 사기탐지 개수',fraud_count_d)
# Out:
# 전처리한 데이터의 사기탐지 개수 2321
# 원본 데이터의 사기탐지 개수 2321

# %%
# Out:
#    UserID        Variable  Correlation
# 0       0          Gender          NaN
# 1       0     Current Age          NaN
# 2       0  Retirement Age          NaN
# 3       0      Birth Year          NaN
# 4       0     Birth Month          NaN
